# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
df = r.json()

df_pvl = pd.DataFrame(df['items'])
RJ_pvl = df_pvl[df_pvl['uf'] == 'RJ']
RJ_pvl
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 89        13594        Município               Rio de Janeiro   3304557  RJ
# 104       11946        Município                    Vassouras   3306206  RJ
# 168       13629           Estado               Rio de Janeiro        33  RJ
# 169       13638        Município                  São Gonçalo   3304904  RJ
# 280       42271        Município               Barra do Piraí   3300308  RJ
# 384       34099        Município                      Resende   3304201  RJ
# 509       42476        Município                  Nova Iguaçu   3303500  RJ
# 551       36529        Município                      Resende   3304201  RJ
# 587       42266        Município              Paty do Alferes   3303856  RJ
# 653       70657        Município                      Niterói   3303302  RJ
# 696       70994        Município                      Valença   3306107  RJ
# ...

# %%
RJ_pvl.status.value_counts()
# Out:
# status
# Deferido                                                 17
# Arquivado                                                 8
# Deferido (PVL-IF)                                         8
# Encaminhado à PGFN com manifestação técnica favorável     7
# Em retificação pelo interessado                           4
# Arquivado por decurso de prazo                            3
# Regularizado                                              2
# Em retificação pelo credor                                1
# Assinado pelo interessado (retificação)                   1
# Em análise                                                1
# Arquivado a pedido                                        1
# Name: count, dtype: int64

# %%
RJ_pvl['data_status'] = RJ_pvl['data_status'].astype(str)
RJ_pvl['ano_status'] = RJ_pvl['data_status'].str.split(pat='/').str.get(2)
RJ_pvl
# Out:
# C:\Users\Maria Fernanda\AppData\Local\Temp\ipykernel_9248\678383552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RJ_pvl['data_status'] = RJ_pvl['data_status'].astype(str)
# C:\Users\Maria Fernanda\AppData\Local\Temp\ipykernel_9248\678383552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RJ_pvl['ano_status'] = RJ_pvl['data_status'].str.split(pat='/').str.get(2)
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# ...

# %%
RJ_pvl.ano_status.value_counts()
# Out:
# ano_status
# 2019    8
# 2020    6
# 2025    4
# 2007    3
# 2018    3
# 2023    3
# 2009    3
# 2016    3
# 2011    3
# 2010    3
# 2013    2
# 2024    2
# 2021    2
# 2008    2
# 2006    2
# 2002    2
# 2022    2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_pvl
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         38882        Município  Colinas do Tocantins   1705508  TO
# 1         45515        Município         São Francisco   3161106  MG
# 2         46451        Município            Comercinho   3117009  MG
# 3         68756        Município            Ananindeua   1500800  PA
# 4         66274        Município           Wall Ferraz   2211704  PI
# ...         ...              ...                   ...       ...  ..
# 4995      68593        Município              Cascavel   4104808  PR
# 4996      70825        Município                Guaíra   4108809  PR
# 4997      64029        Município          Itamarandiba   3132503  MG
# 4998      68346           Estado                 Bahia        29  BA
# 4999      60057        Município                Paraty   3303807  RJ
#
#                    num_pvl                                             status  \
# ...

# %%
def consulta_dado(uf, tipo_interessado):
    dados_consulta = df_pvl[(df_pvl['uf'] == uf) & (df_pvl['tipo_interessado'] == tipo_interessado)]
    return dados_consulta

uf = 'MG'
tipo_interessado = 'Estado'

resultado_consulta = consulta_dado(uf, tipo_interessado)

MG = pd.DataFrame(resultado_consulta)
MG
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 170       13641           Estado  Minas Gerais        31  MG    None
# 1128      13618           Estado  Minas Gerais        31  MG    None
# 1482       7435           Estado  Minas Gerais        31  MG    None
# 4342       6811           Estado  Minas Gerais        31  MG    None
# 4946      13602           Estado  Minas Gerais        31  MG    None
#
#                                                  status          num_processo  \
# 170                                            Deferido  19405.000042/2004-58
# 1128  Encaminhado à PGFN com manifestação técnica fa...  19405.000037/2006-15
# 1482  Encaminhado à PGFN com manifestação técnica fa...  17944.000576/2009-66
# 4342  Encaminhado à PGFN com manifestação técnica fa...  17944.000435/2008-62
# 4946  Encaminhado à PGFN com manifestação técnica fa...  19405.000034/2005-92
#
#             data_protocolo                                      tipo_operacao  \
# ...

# %%
MG.status.value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    4
# Deferido                                                 1
# Name: count, dtype: int64

# %%
BA_pvl = df_pvl[df_pvl['uf'] == 'BA']
BA_pvl_municipios = BA_pvl[BA_pvl['tipo_interessado'] == 'Município']

BA_pvl_municipios.interessado.value_counts()
# Out:
# interessado
# Amargosa                  6
# Luís Eduardo Magalhães    5
# Mata de São João          3
# Porto Seguro              3
# Salvador                  3
#                          ..
# Saubara                   1
# Barro Alto                1
# Caatiba                   1
# Prado                     1
# Ibicuí                    1
# Name: count, Length: 111, dtype: int64

# %%
BA_pvl_estado = BA_pvl[BA_pvl['tipo_interessado'] == 'Estado']
BA_pvl_estado.to_csv('BA_pvl_ESTADO.csv', index = False, sep=';', decimal=',')
